# %%
using Pkg
Pkg.add("Plots")
Pkg.add("StatsPlots")
using Plots, StatsPlots
# Out:
#    Resolving package versions...
#   No Changes to `~/.julia/environments/v1.7/Project.toml`
#   No Changes to `~/.julia/environments/v1.7/Manifest.toml`
#    Resolving package versions...
#   No Changes to `~/.julia/environments/v1.7/Project.toml`
#   No Changes to `~/.julia/environments/v1.7/Manifest.toml`

# %% [markdown]
# ## Bar charts

# %%
a1 = [40.74, 25.25, 58.31, 54.89]
a2 = [20.09, 1.02, 28.15, 35.02]
a3 = [6.56, 8.98, 13.07, 5.06]
a4 = [0, 0, 0, 0]
a5 = [25.07, 39.77, 36.22, 37.03]
# Out:
# 4-element Vector{Float64}:
#  25.07
#  39.77
#  36.22
#  37.03

# %%
id = ["1" "2" "3" "4" "5"]
# Out:
# 1×5 Matrix{String}:
#  "1"  "2"  "3"  "4"  "5"

# %%
color = ["red" "blue" "green" "purple" "yellow"]
# Out:
# 1×5 Matrix{String}:
#  "red"  "blue"  "green"  "purple"  "yellow"

# %%
ticklabel = ["Li⁺" "Na⁺" "Mg⁺²" "Zn⁺²"]
# Out:
# 1×4 Matrix{String}:
#  "Li⁺"  "Na⁺"  "Mg⁺²"  "Zn⁺²"

# %%
groupedbar([a1 a2 a3 a4 a5], bar_position = :dodge, bar_width=0.7, xticks=(1:12, ticklabel), labels=id, colour=color)

# %%
b1 = [21.32, 0.675, 44.18, 60.12]
b2 = [10.43, 0.900, 29.99, 30.75]
b3 = [3.52, 10.84, 10.46, 6.97]
b4 = [0, 0, 0, 0]
b5 = [12.22, 15.49, 30.81, 26.56]
# Out:
# 4-element Vector{Float64}:
#  12.22
#  15.49
#  30.81
#  26.56

# %%
groupedbar([b1 b2 b3 b4 b5], bar_position = :dodge, bar_width=0.7, xticks=(1:12, ticklabel), labels=id, colour=color)

# %%
c1 = [38.40, 17.67, 50.50, 59.77]
c2 = [23.84, 0.982, 27.68, 26.10]
c3 = [4.01, 11.66, 9.65, 3.84]
c4 = [0, 0, 0, 0]
c5 = [32.05, 29.43, 35.76, 28.94]
# Out:
# 4-element Vector{Float64}:
#  32.05
#  29.43
#  35.76
#  28.94

# %%
groupedbar([c1 c2 c3 c4 c5], bar_position = :dodge, bar_width=0.7, xticks=(1:12, ticklabel), labels=id, colour=color)
